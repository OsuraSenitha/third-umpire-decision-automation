# %%
from google.colab import drive
drive.mount("/content/drive")

# %env DRIVE_SRC=/content/drive/MyDrive/IIT-Projects/third-umpire-automation/src/
# %cd /content
# copy drive src
# !mkdir ./src
# !cp -r $DRIVE_SRC/* ./src/
# Out:
# env: DRIVE_SRC=/content/drive/MyDrive/IIT-Projects/third-umpire-automation/src/
# /content

# %%
# %env DRIVE_SRC=/content/drive/MyDrive/Work/IIT-Projects/third-umpire-automation/src/
# Out:
# env: DRIVE_SRC=/content/drive/MyDrive/Work/IIT-Projects/third-umpire-automation/src/

# %%
# copy current files back to drive
# !cp -r ./src/* $DRIVE_SRC

# %%
# from src.data.download import download as download_data
# download_data("cricket-semantic")

# %%
from src.data.analyze import img_sizes as analyze_img_sizes
imgs_path = "/content/data/cricket-semantic-segmentation/images"
analyze_img_sizes(imgs_path, lambda name: "__" not in name)
# Out:
# [{'size': '(1920, 1080)', 'count': 298}]

# %%
import matplotlib.pyplot as plt
img = plt.imread("/content/data/cricket-semantic-segmentation/images/2022-08-24 (298).png")
plt.text(0, 0, "hi", color="red") 
plt.imshow(img)

# %%
thing_list = [False, True, False]
thing_list.index(True) if True in thing_list else -1
# Out:
# 1
