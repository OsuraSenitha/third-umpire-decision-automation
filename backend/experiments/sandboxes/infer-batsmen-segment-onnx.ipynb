# %%
import os
import sys
import matplotlib.pyplot as plt
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)

from src.infer.yolo_image_segment import ImageSegmentModel
model_path = "../../model-weights/yolov8_batsmen_image_segment.onnx"

# Initialize YOLOv8 Instance Segmentator
segmentor = ImageSegmentModel(model_path, conf_thres=0.3, iou_thres=0.5)

img_path = "../data/test/ms-dhoni-run-out-in-2019-wc-semi-finals.jpg"

# Detect Objects
boundary = segmentor(img_path, [0,0,600,600])
# Out:
# 1 <class 'numpy.ndarray'>

# %%
import cv2 as cv
from src.data.visualize import drawSegments
img = cv.imread(img_path)
drawn_img = drawSegments(img, [[0, *boundary]])
plt.imshow(drawn_img)
plt.show()
