# %%
import os
import sys

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)

from src.infer.object_detect import ObjectDetectModel

# %%
onnx_path = "../../training-jobs/detect/cricket-object-detect17/weights/best.onnx"
img_path = "../data/Cricket-Semantic-Segmentation[Native]/images/2022-08-24 (14).png"

model = ObjectDetectModel(onnx_path)
# output = model(img_path, 0.3)
output = model(img_path)
output.show_image()

# %%
output.tolist()
# Out:
# [['Wicket', '842', '673', '871', '922', '0.7389125'],
#  ['Batsmen', '1158', '347', '1622', '963', '0.71167135']]
