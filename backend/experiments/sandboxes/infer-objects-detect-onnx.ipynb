# %%
import os
import sys

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)

from src.ml.object_detector import ObjectDetectModel

# %%
onnx_path = "../../training-jobs/detect/cricket-object-detect17/weights/best.onnx"
img_path = "../data/test/2022-08-24 (13).png"

model = ObjectDetectModel(onnx_path)
# output = model(img_path, 0.3)
output = model(img_path)
output.show_image()

# [
#     [x,y,w,h,0.12,0.12],
#     [x,y,w,h,0.65,0.12],
#     [x,y,w,h,0.23,0.12],
#     [x,y,w,h,0.45,0.87],
#     ....
# ]
# Out:
# Inference outputs shape (1, 6, 8400)
# Processed boxes shape (2, 4)
# Processed boxes
#  [[0.59270835 0.35185185 0.78802085 0.84444445]
#  [0.88385415 0.62314814 0.90208334 0.84166664]]
